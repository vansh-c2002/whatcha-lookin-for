#         38.84698413,  38.98630385,  39.03274376,  39.26494331,
#         39.63646259,  39.9847619 ,  40.26340136,  40.42594104,
#         40.79746032,  41.67981859,  41.7262585 ,  42.4460771 ,
#         42.74793651,  47.55446712,  47.92598639,  48.20462585,
#         48.59936508,  48.78512472,  48.9476644 ,  49.13342404,
#         50.64272109,  50.99102041,  51.10712018,  51.61795918,
#         51.80371882,  53.93995465,  54.14893424,  54.4275737 ,
#         54.79909297,  55.1938322 ,  55.47247166,  55.58857143,
#         55.79755102,  55.98331066,  56.40126984,  56.63346939,
#         56.86566893,  56.98176871,  57.37650794,  57.49260771,
#         57.74802721,  57.86412698,  58.02666667,  59.58240363,
#         59.83782313,  60.95238095,  61.1845805 ,  61.30068027,
#         62.64743764,  62.69387755,  62.76353741,  62.87963719,
#         63.25115646,  63.59945578,  63.78521542,  63.92453515,
#         64.2031746 ,  65.54993197,  65.71247166,  66.33941043,
#         66.68770975,  70.68154195,  70.72798186,  70.96018141,
#         71.95863946,  72.30693878,  93.15845805,  93.32099773,
#         93.69251701,  93.9014966 ,  94.24979592,  94.59809524,
#         94.87673469,  94.94639456,  95.94485261,  96.20027211,
#         96.43247166,  96.68789116,  96.75755102,  97.10585034,
#         97.1755102 ,  97.45414966,  97.94176871,  99.75292517,
#        100.17088435, 100.47274376, 100.63528345, 100.86748299,
#        101.86594104, 102.19102041, 102.37678005, 102.53931973,
#        102.67863946, 103.07337868, 103.21269841, 103.44489796,
#        103.49133787, 103.74675737, 104.81487528, 105.04707483,
#        105.25605442, 105.51147392, 105.55791383, 106.1384127 ,
#        106.46349206, 106.67247166, 106.78857143, 106.97433107,
#        108.25142857, 108.29786848, 108.59972789, 108.97124717,
#        109.29632653, 109.73750567, 111.08426304, 111.33968254,
#        111.45578231, 111.94340136, 112.26848073, 117.12145125,
#        117.30721088, 117.51619048, 117.6555102 , 118.28244898,
#        118.44498866, 118.60752834, 120.67410431, 120.90630385,
#        121.02240363, 121.20816327, 121.57968254, 121.6493424 ,
#        121.78866213, 121.99764172, 123.55337868, 123.62303855,
#        123.901678  , 124.29641723, 124.50539683, 124.92335601,
#        125.01623583, 125.1323356 , 125.57351474, 126.78095238,
#        126.94349206, 127.31501134, 127.52399093, 127.8955102 ,
#        127.94195011, 128.05804989, 128.1044898 , 128.49922902,
#        128.54566893, 131.40172336, 131.68036281, 131.95900227,
#        132.02866213, 132.23764172, 132.56272109, 133.14321995,
#        133.39863946, 133.49151927, 133.81659864, 134.141678  ,
#        134.28099773, 134.58285714, 134.79183673, 135.07047619,
#        135.23301587, 140.22530612, 140.3414059 , 140.75936508])

# %%
print(len(ailh_bass)/sr)
print(len(ailh_vocals)/sr)
print(len(dm_bass)/sr)
# Out:
# 164.96621315192743
# 164.96621315192743
# 260.73687074829934

# %%
print(np.mean(librosa.feature.rms(y=ailh_bass)[0]))
print(np.mean(librosa.feature.rms(y=ailh_vocals)[0]))
print(np.mean(librosa.feature.rms(y=dm_bass)[0]))
# Out:
# 6.236887e-05
# 0.037982818
# 0.042678505

# %%
def detect_instrument_presence(stem_audio, sr=22050):
    
    """Simple energy-based detection"""
    
    # Average loudness/energy
    mean_rms_energy = np.mean(librosa.feature.rms(y=stem_audio)[0])
    
    # Threshold (tune this!)
    energy_threshold = 0.0001  # Adjust based on your data
    
    return 1 if mean_rms_energy > energy_threshold else 0

# %% [markdown]
# ## Database Generation

# %%
import sqlite3

# %%
conn = sqlite3.connect('song_database.db')

# %%
# Instantiates the database

def create_tables(conn):
    cursor = conn.cursor()
    cursor.execute('''
    CREATE TABLE IF NOT EXISTS songs (
        song_id INTEGER PRIMARY KEY AUTOINCREMENT,
        title TEXT NOT NULL,
        artist TEXT,
        duration REAL,
        vocals BOOLEAN,
        bass BOOLEAN,
        drums BOOLEAN,
        others BOOLEAN
    )
    ''')
    conn.commit()

def insert_song(conn, title, artist, duration, vocals, bass, drums, others):
    cursor = conn.cursor()
    cursor.execute('''
    INSERT INTO songs (title, artist, duration, vocals, bass, drums, others)
    VALUES (?, ?, ?, ?, ?, ?, ?)
    ''', (title, artist, duration, vocals, bass, drums, others))
    conn.commit()
    return cursor.lastrowid  # Returns the song_id

def fetch_all_songs(conn):
    cursor = conn.cursor()
    cursor.execute('SELECT * FROM songs')
    return cursor.fetchall()

# %% [markdown]
# I could add a BLOB here, if need be? idk if i wanna store that in my database though bcs I don't want a huge database with all the audio files. The info from them is less storage

# %%
# !pip install -U demucs
# Out:
# Collecting demucs
#   Using cached demucs-4.0.1-py3-none-any.whl
# Collecting dora-search (from demucs)
#   Using cached dora_search-0.1.12-py3-none-any.whl
# Collecting einops (from demucs)
#   Using cached einops-0.8.1-py3-none-any.whl.metadata (13 kB)
# Collecting julius>=0.2.3 (from demucs)
#   Using cached julius-0.2.7-py3-none-any.whl
# Collecting lameenc>=1.2 (from demucs)
#   Using cached lameenc-1.8.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (9.9 kB)
# Collecting openunmix (from demucs)
#   Using cached openunmix-1.3.0-py3-none-any.whl.metadata (17 kB)
# Collecting pyyaml (from demucs)
#   Using cached PyYAML-6.0.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (2.1 kB)
# Collecting torch>=1.8.1 (from demucs)
#   Using cached torch-2.7.1-cp313-none-macosx_11_0_arm64.whl.metadata (29 kB)
# Collecting torchaudio>=0.8 (from demucs)
#   Using cached torchaudio-2.7.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Collecting tqdm (from demucs)
#   Using cached tqdm-4.67.1-py3-none-any.whl.metadata (57 kB)
# Collecting filelock (from torch>=1.8.1->demucs)
#   Using cached filelock-3.18.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/vanshc/Documents/GitHub/whatcha-lookin-for/.venv/lib/python3.13/site-packages (from torch>=1.8.1->demucs) (4.14.1)
# Collecting setuptools (from torch>=1.8.1->demucs)
#   Using cached setuptools-80.9.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch>=1.8.1->demucs)
#   Using cached sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx (from torch>=1.8.1->demucs)
#   Using cached networkx-3.5-py3-none-any.whl.metadata (6.3 kB)
# Collecting jinja2 (from torch>=1.8.1->demucs)
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting fsspec (from torch>=1.8.1->demucs)
#   Downloading fsspec-2025.7.0-py3-none-any.whl.metadata (12 kB)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.8.1->demucs)
#   Using cached mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting omegaconf (from dora-search->demucs)
#   Using cached omegaconf-2.3.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting retrying (from dora-search->demucs)
#   Using cached retrying-1.4.0-py3-none-any.whl.metadata (7.5 kB)
# Collecting submitit (from dora-search->demucs)
#   Using cached submitit-1.5.3-py3-none-any.whl.metadata (7.9 kB)
# Collecting treetable (from dora-search->demucs)
#   Using cached treetable-0.2.5-py3-none-any.whl
# Collecting MarkupSafe>=2.0 (from jinja2->torch>=1.8.1->demucs)
#   Using cached MarkupSafe-3.0.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (4.0 kB)
# Collecting antlr4-python3-runtime==4.9.* (from omegaconf->dora-search->demucs)
#   Using cached antlr4_python3_runtime-4.9.3-py3-none-any.whl
# Requirement already satisfied: numpy in /Users/vanshc/Documents/GitHub/whatcha-lookin-for/.venv/lib/python3.13/site-packages (from openunmix->demucs) (2.2.6)
# Collecting cloudpickle>=1.2.1 (from submitit->dora-search->demucs)
#   Using cached cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Using cached lameenc-1.8.1-cp313-cp313-macosx_11_0_arm64.whl (182 kB)
# Using cached torch-2.7.1-cp313-none-macosx_11_0_arm64.whl (68.6 MB)
# Using cached sympy-1.14.0-py3-none-any.whl (6.3 MB)
# Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Using cached torchaudio-2.7.1-cp313-cp313-macosx_11_0_arm64.whl (1.8 MB)
# Using cached einops-0.8.1-py3-none-any.whl (64 kB)
# Using cached filelock-3.18.0-py3-none-any.whl (16 kB)
# Downloading fsspec-2025.7.0-py3-none-any.whl (199 kB)
# Using cached jinja2-3.1.6-py3-none-any.whl (134 kB)
# Using cached MarkupSafe-3.0.2-cp313-cp313-macosx_11_0_arm64.whl (12 kB)
# Using cached networkx-3.5-py3-none-any.whl (2.0 MB)
# Using cached omegaconf-2.3.0-py3-none-any.whl (79 kB)
# Using cached PyYAML-6.0.2-cp313-cp313-macosx_11_0_arm64.whl (171 kB)
# Using cached openunmix-1.3.0-py3-none-any.whl (40 kB)
# Using cached retrying-1.4.0-py3-none-any.whl (11 kB)
# Using cached setuptools-80.9.0-py3-none-any.whl (1.2 MB)
# Using cached submitit-1.5.3-py3-none-any.whl (75 kB)
# Using cached cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Installing collected packages: mpmath, lameenc, antlr4-python3-runtime, treetable, tqdm, sympy, setuptools, retrying, pyyaml, networkx, MarkupSafe, fsspec, filelock, einops, cloudpickle, submitit, omegaconf, jinja2, torch, torchaudio, julius, dora-search, openunmix, demucs
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24/24 [demucs]21/24 [dora-search]
# Successfully installed MarkupSafe-3.0.2 antlr4-python3-runtime-4.9.3 cloudpickle-3.1.1 demucs-4.0.1 dora-search-0.1.12 einops-0.8.1 filelock-3.18.0 fsspec-2025.7.0 jinja2-3.1.6 julius-0.2.7 lameenc-1.8.1 mpmath-1.3.0 networkx-3.5 omegaconf-2.3.0 openunmix-1.3.0 pyyaml-6.0.2 retrying-1.4.0 setuptools-80.9.0 submitit-1.5.3 sympy-1.14.0 torch-2.7.1 torchaudio-2.7.1 tqdm-4.67.1 treetable-0.2.5

# %%
create_tables(conn)
"/Users/vanshc/Desktop/Split/separated/htdemucs_ft/DELETE_Passenger_And_I_Love_Her_(Official_Video)/vocals.wav"

def separate_stems(parent_folder):
    for song_file in Path(parent_folder).glob("*.mp3"):
        # y, sr = librosa.load(song_file)
        # duration = librosa.get_duration(y=y, sr=sr)
        
        command = [
                "demucs",
                "-n", "htdemucs",
                "-o", str(parent_folder), # maybe add a /trying or some subfolder here
                str(song_file)
            ]
        
        subprocess.run(command, check=True)

# %%
parent_folder = Path("/Users/vanshc/Desktop/Split")

def add_to_database(parent_folder):
    new = parent_folder / "separated/htdemucs"

    for file in new.glob("*"):
        print(file)
# Out:
# /Users/vanshc/Desktop/Split/separated/.DS_Store
# /Users/vanshc/Desktop/Split/separated/htdemucs_ft
# /Users/vanshc/Desktop/Split/separated/htdemucs_6s
# /Users/vanshc/Desktop/Split/separated/htdemucs

# %%
def detect_basic_info(song_folder):
    artist, title = os.path.basename(song_folder).split(" - ", 1)
    sample = librosa.load(song_folder / 'vocals.wav', sr=22050)
    duration = librosa.get_duration(y=sample, sr=22050)

    return title.strip(), artist.strip(), duration

# %%
separate_stems("/Users/vanshc/Desktop/Songs/trial")
# Out:
# Selected model is a bag of 1 models. You will see that many progress bars per track.
# Separated tracks will be stored in /Users/vanshc/Desktop/Songs/trial/htdemucs
# Separating track /Users/vanshc/Desktop/Songs/trial/YuraSoop - Summer Funky Groove.mp3
# 100%|██████████████████████████████████████████████| 140.39999999999998/140.39999999999998 [01:16<00:00,  1.83seconds/s]

# %%
detect_basic_info("/Users/vanshc/Desktop/Songs/trial/htdemucs/YuraSoop - Summer Funky Groove")
# Out:
# ('Summer Funky Groove', 'YuraSoop', 136.54204081632653)

# %%
def detect_basic_info(song_folder):
    artist, title = os.path.basename(song_folder).split(" - ", 1)
    sample = librosa.load(song_folder / 'vocals.wav', sr=22050)
    duration = librosa.get_duration(y=sample, sr=22050)

    return title.strip(), artist.strip(), duration

# %%
def detect_instrument_presence_stem(stem_audio, sr=22050):
    
    # Average loudness/energy
    mean_rms_energy = np.mean(librosa.feature.rms(y=stem_audio)[0])
    
    # Threshold (tune this!)
    energy_threshold = 0.0001  # Adjust based on your data
    
    return 1 if mean_rms_energy > energy_threshold else 0


def detect_instrument_presence_song(song_folder):

    stem_files = {}
    for audio_file in song_folder.glob("*.wav"):
        stem_name = audio_file.stem  
        stem_files[stem_name] = audio_file # bass.wav: file_path

    expected_stems = ['vocals', 'drums', 'bass', 'other']
    results = {}
    
    # Check each expected stem
    for stem_name in expected_stems:
        if stem_name in stem_files:
            try:
                # Load the stem audio
                stem_audio, _ = librosa.load(stem_files[stem_name], sr=22050)
                
                # Run your detection method
                presence = detect_instrument_presence_stem(stem_audio)
                results[stem_name] = presence
                
            except Exception as e:
                print(f"  Error analyzing {stem_name}: {e}")
                results[stem_name] = 0
        else:
            print(f"  Warning: {stem_name}.wav not found")
            results[stem_name] = 0
    
    return results['vocals'], results['drums'], results['bass'], results['other']

# %%
conn = sqlite3.connect('song_database.db')
create_tables(conn)

vocals, drums, bass, other = detect_instrument_presence_song(Path("/Users/vanshc/Desktop/Songs/trial/htdemucs/YuraSoop - Summer Funky Groove"))
title, artist, duration = detect_basic_info(Path("/Users/vanshc/Desktop/Songs/trial/htdemucs/YuraSoop - Summer Funky Groove"))
insert_song(conn, title, artist, duration, vocals, bass, drums, other)
# Out:
# 1
